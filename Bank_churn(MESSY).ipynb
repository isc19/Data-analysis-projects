# %%
import pandas as pd

# %%
import numpy as py

# %%
import matplotlib.pyplot as plt

# %%
# %pip install seaborn

# %%
import seaborn as sns

# %%
#import the dataset
df = pd.read_csv('Bank_churn.csv')

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0    15634602  Hargrave          619       FRA  Female  42.0       2
# 1    15647311      Hill          608     Spain  Female  41.0       1
# 2    15619304      Onio          502    French  Female  42.0       8
# 3    15701354      Boni          699       FRA  Female  39.0       1
# 4    15737888  Mitchell          850     Spain  Female  43.0       2
#
#    EstimatedSalary    Balance  NumOfProducts HasCrCard  Tenure.1  \
# 0        101348.88       0.00              1       Yes         2
# 1        112542.58   83807.86              1       Yes         1
# 2        113931.57  159660.80              3        No         8
# 3         93826.63       0.00              2        No         1
# 4         79084.10  125510.82              1       Yes         2
#
#   IsActiveMember  Exited
# 0            Yes       1
# 1            Yes       0
# 2             No       1
# 3             No       0
# 4            Yes       0

# %%
#Need to clean the data
unique_Geography = df['Geography'].unique()

# %%
print(unique_Geography)
# Out:
# ['FRA' 'Spain' 'French' 'France' 'Germany']

# %% [markdown]
# ## There are 3 different options for France so we need to replace 'FRA' and 'French' with 'France

# %%
df = df.replace(to_replace= ["FRA", "French"], value = "France")

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female  42.0       2
# 1    15647311      Hill          608     Spain  Female  41.0       1
# 2    15619304      Onio          502    France  Female  42.0       8
# 3    15701354      Boni          699    France  Female  39.0       1
# 4    15737888  Mitchell          850     Spain  Female  43.0       2
#
#    EstimatedSalary    Balance  NumOfProducts HasCrCard  Tenure.1  \
# 0        101348.88       0.00              1       Yes         2
# 1        112542.58   83807.86              1       Yes         1
# 2        113931.57  159660.80              3        No         8
# 3         93826.63       0.00              2        No         1
# 4         79084.10  125510.82              1       Yes         2
#
#   IsActiveMember  Exited
# 0            Yes       1
# 1            Yes       0
# 2             No       1
# 3             No       0
# 4            Yes       0

# %%
unique_Geography = df['Geography'].unique()
print(unique_Geography)
# Out:
# ['France' 'Spain' 'Germany']

# %% [markdown]
# ## Notice we have the column 'tenure' twice in the df so we need to drop one of them

# %%
df = df.drop("Tenure.1", axis = 'columns')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10001 non-null  int64
#  1   Surname          9998 non-null   object
#  2   CreditScore      10001 non-null  int64
#  3   Geography        10001 non-null  object
#  4   Gender           10001 non-null  object
#  5   Age              9998 non-null   float64
#  6   Tenure           10001 non-null  int64
#  7   EstimatedSalary  10001 non-null  float64
#  8   Balance          10001 non-null  float64
#  9   NumOfProducts    10001 non-null  int64
#  10  HasCrCard        10001 non-null  object
#  11  IsActiveMember   10001 non-null  object
#  12  Exited           10001 non-null  int64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 820.5+ KB

# %% [markdown]
# ## Need to check if there are any duplicated CustomerId in the df

# %%
df.duplicated('CustomerId').sum()
# Out:
# np.int64(1)

# %% [markdown]
# ## There is a duplicated CustomerId in the df so let us drop the row of the duplicated Id

# %%
df = df.drop_duplicates(subset =['CustomerId'])

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female  42.0       2
# 1    15647311      Hill          608     Spain  Female  41.0       1
# 2    15619304      Onio          502    France  Female  42.0       8
# 3    15701354      Boni          699    France  Female  39.0       1
# 4    15737888  Mitchell          850     Spain  Female  43.0       2
#
#    EstimatedSalary    Balance  NumOfProducts HasCrCard IsActiveMember  Exited
# 0        101348.88       0.00              1       Yes            Yes       1
# 1        112542.58   83807.86              1       Yes            Yes       0
# 2        113931.57  159660.80              3        No             No       1
# 3         93826.63       0.00              2        No             No       0
# 4         79084.10  125510.82              1       Yes            Yes       0

# %% [markdown]
# ## Make the CustomerId the df index

# %%
df = df.set_index('CustomerId')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 15634602 to 15628319
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Surname          9997 non-null   object
#  1   CreditScore      10000 non-null  int64
#  2   Geography        10000 non-null  object
#  3   Gender           10000 non-null  object
#  4   Age              9997 non-null   float64
#  5   Tenure           10000 non-null  int64
#  6   EstimatedSalary  10000 non-null  float64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  object
#  10  IsActiveMember   10000 non-null  object
#  11  Exited           10000 non-null  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 820.3+ KB

# %% [markdown]
# ## We can see now that there are 3 null values for surname and age
# ### For the surname one could go back to the database and search for the CustomerId and the corresponding surname. However for the purpose of this project, I will replace the null values with 'NotProvided'
#
# ### For age, I will replace with a statistical value (the median)

# %%
new_surname = { "Surname": "NotProvided"
}
df = df.fillna(value=new_surname)

age_median = df['Age'].median()
df['Age'] = df['Age'].fillna(value=age_median)
df
# Out:
#               Surname  CreditScore Geography  Gender   Age  Tenure  \
# CustomerId
# 15634602     Hargrave          619    France  Female  42.0       2
# 15647311         Hill          608     Spain  Female  41.0       1
# 15619304         Onio          502    France  Female  42.0       8
# 15701354         Boni          699    France  Female  39.0       1
# 15737888     Mitchell          850     Spain  Female  43.0       2
# ...               ...          ...       ...     ...   ...     ...
# 15606229     Obijiaku          771    France    Male  39.0       5
# 15569892    Johnstone          516    France    Male  35.0      10
# 15584532          Liu          709    France  Female  36.0       7
# 15682355    Sabbatini          772   Germany    Male  42.0       3
# 15628319       Walker          792    France  Female  28.0       4
#
#             EstimatedSalary    Balance  NumOfProducts HasCrCard  \
# CustomerId
# 15634602          101348.88       0.00              1       Yes
# 15647311          112542.58   83807.86              1       Yes
# 15619304          113931.57  159660.80              3        No
# 15701354           93826.63       0.00              2        No
# 15737888           79084.10  125510.82              1       Yes
# ...                     ...        ...            ...       ...
# 15606229           96270.64       0.00              2        No
# 15569892          101699.77   57369.61              1       Yes
# 15584532           42085.58       0.00              1       Yes
# 15682355           92888.52   75075.31              2        No
# 15628319           38190.78  130142.79              1        No
#
#            IsActiveMember  Exited
# CustomerId
# 15634602              Yes       1
# 15647311              Yes       0
# 15619304               No       1
# 15701354               No       0
# 15737888              Yes       0
# ...                   ...     ...
# 15606229               No       0
# 15569892              Yes       0
# 15584532              Yes       1
# 15682355               No       1
# 15628319               No       0
#
# [10000 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 15634602 to 15628319
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Surname          10000 non-null  object
#  1   CreditScore      10000 non-null  int64
#  2   Geography        10000 non-null  object
#  3   Gender           10000 non-null  object
#  4   Age              10000 non-null  float64
#  5   Tenure           10000 non-null  int64
#  6   EstimatedSalary  10000 non-null  float64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  object
#  10  IsActiveMember   10000 non-null  object
#  11  Exited           10000 non-null  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 820.3+ KB

# %% [markdown]
# ## Let us check that estimated salary is as it should be and that there are no negative values

# %%
df.sort_values(by='EstimatedSalary')
# Out:
#                 Surname  CreditScore Geography  Gender   Age  Tenure  \
# CustomerId
# 15580203    NotProvided          674     Spain    Male  37.0       6
# 15756954    NotProvided          538    France  Female  37.0       2
# 15728693    NotProvided          574   Germany  Female  37.0       3
# 15791053       Lucciano          709   Germany    Male  45.0       4
# 15679693         Walker          625    France    Male  31.0       5
# ...                 ...          ...       ...     ...   ...     ...
# 15709136          Adams          620    France    Male  28.0       8
# 15762331           Moss          569    France    Male  37.0       9
# 15697270         Gannon          608     Spain    Male  27.0       4
# 15634359           Dyer          639   Germany  Female  41.0       5
# 15662021       Lucciano          685     Spain  Female  42.0       2
#
#             EstimatedSalary    Balance  NumOfProducts HasCrCard  \
# CustomerId
# 15580203         -999999.00  120193.42              1        No
# 15756954         -999999.00       0.00              1       Yes
# 15728693         -999999.00  141349.43              1       Yes
# 15791053              11.58  122917.71              1       Yes
# 15679693              90.07       0.00              2       Yes
# ...                     ...        ...            ...       ...
# 15709136          199909.32       0.00              2       Yes
# 15762331          199929.17  178755.84              1        No
# 15697270          199953.33  153325.10              1       Yes
# 15634359          199970.74   98635.77              1        No
# 15662021          199992.48       0.00              2        No
#
#            IsActiveMember  Exited
# CustomerId
# 15580203               No       0
# 15756954              Yes       0
# 15728693              Yes       0
# 15791053              Yes       1
# 15679693              Yes       0
# ...                   ...     ...
# 15709136              Yes       0
# 15762331               No       0
# 15697270              Yes       0
# 15634359               No       0
# 15662021               No       0
#
# [10000 rows x 12 columns]

# %% [markdown]
# ### We can replace the negative values with a statistical value (the median)

# %%
est_salary_median = df['EstimatedSalary'].median()
df['EstimatedSalary'] = df['EstimatedSalary'].replace(to_replace = -999999.00, value = est_salary_median)

# %%
df.sort_values(by='EstimatedSalary')
# Out:
#              Surname  CreditScore Geography  Gender   Age  Tenure  \
# CustomerId
# 15791053    Lucciano          709   Germany    Male  45.0       4
# 15679693      Walker          625    France    Male  31.0       5
# 15786463       Hsing          645   Germany  Female  59.0       8
# 15639662    Phillips          710    France    Male  38.0       2
# 15602851      Ozioma          629    France    Male  40.0       9
# ...              ...          ...       ...     ...   ...     ...
# 15709136       Adams          620    France    Male  28.0       8
# 15762331        Moss          569    France    Male  37.0       9
# 15697270      Gannon          608     Spain    Male  27.0       4
# 15634359        Dyer          639   Germany  Female  41.0       5
# 15662021    Lucciano          685     Spain  Female  42.0       2
#
#             EstimatedSalary    Balance  NumOfProducts HasCrCard  \
# CustomerId
# 15791053              11.58  122917.71              1       Yes
# 15679693              90.07       0.00              2       Yes
# 15786463              91.75  121669.93              2        No
# 15639662              96.27       0.00              2        No
# 15602851             106.67       0.00              1        No
# ...                     ...        ...            ...       ...
# 15709136          199909.32       0.00              2       Yes
# 15762331          199929.17  178755.84              1        No
# 15697270          199953.33  153325.10              1       Yes
# 15634359          199970.74   98635.77              1        No
# 15662021          199992.48       0.00              2        No
#
#            IsActiveMember  Exited
# CustomerId
# 15791053              Yes       1
# 15679693              Yes       0
# 15786463               No       1
# 15639662               No       0
# 15602851               No       0
# ...                   ...     ...
# 15709136              Yes       0
# 15762331               No       0
# 15697270              Yes       0
# 15634359               No       0
# 15662021               No       0
#
# [10000 rows x 12 columns]

# %% [markdown]
# # Analysing the data

# %% [markdown]
# - What attributes are more common among churners than non-churners? Can churn be predicted using the variables in the data?
#
# - What do the overall demographics of the bank's customers look like?
#
# - Is there a difference between German, French, and Spanish customers i-n terms of account behavior?
#
# - What types of segments exist within the bank's customers?

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df.replace({'Geography':{'France':2 , 'Germany':1 , 'Spain':0}}, inplace=True)
# Out:
# <ipython-input-41-d6f694324987>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'Geography':{'France':2 , 'Germany':1 , 'Spain':0}}, inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df.replace({'Gender':{'Male':0, 'Female':1}}, inplace=True)
# Out:
# <ipython-input-44-1bfcf9037084>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'Gender':{'Male':0, 'Female':1}}, inplace=True)

# %%
df['NumOfProducts'].value_counts()
# Out:
# NumOfProducts
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: count, dtype: int64

# %% [markdown]
# ## As the count value for 3 and 4 products used is very small compared to 1 and 2 we are going to clump 3 and 4 togther with 2 so we avoid working with small sample sizes

# %%
df.replace({'NumOfProducts':{1:0, 2:1 , 3:1 , 4:1}}, inplace=True)

# %%
df['HasCrCard'].value_counts()
# Out:
# HasCrCard
# Yes    5151
# No     4849
# Name: count, dtype: int64

# %%
df.replace({'HasCrCard':{'Yes':1, 'No': 0}}, inplace=True)
# Out:
# <ipython-input-54-6af46ad6a8bd>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'HasCrCard':{'Yes':1, 'No': 0}}, inplace=True)

# %%
df['IsActiveMember'].value_counts()
# Out:
# IsActiveMember
# Yes    5151
# No     4849
# Name: count, dtype: int64
